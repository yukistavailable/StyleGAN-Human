# %%
import os
import cv2, matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
import numpy as np
from projector import run_projection_human_from_outside

# %%
image2StyleGAN_method = True
# network_pkl = 'models/stylegan2_1024.pkl'
network_pkl = 'models/stylegan_human_v2_512.pkl'
target_fname = '../exec/input/ikuchan_256_512_2.jpeg'
outdir = 'out/style_human_projection'
out_path = os.path.join(outdir, 'proj.png')
save_video = False
num_steps = 3
seed = 303

# %%
w = run_projection_human_from_outside(image2StyleGAN_method, network_pkl, target_fname, outdir, save_video, seed, num_steps)
# Out:
# Loading networks from "models/stylegan_human_v2_512.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# step    1/3: dist 2.43 loss 39444.21
# step    2/3: dist 1.92 loss 110230.62
# step    3/3: dist 1.11 loss 102225.48
# Elapsed: 38.2 s

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

image = Image.open(target_fname)
image_array = np.asarray(image)
ax1.imshow(image_array)

image = Image.open(out_path)
image_array = np.asarray(image)
ax2.imshow(image_array)
