# %%
import os
import cv2, matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
import numpy as np
from style_mixing import generate_style_mix_human_from_outside

# %%
# network_pkl = 'models/stylegan2_1024.pkl'
network_pkl = 'models/stylegan_human_v2_512.pkl'
outdir = 'out/stylegan_human_mixing/'
out_path = os.path.join(outdir, 'grid.png')
truncation_psi = 1.0
# 'const', 'random', or 'none'
noise_mode = 'const'
col_styles = [0,2,4,6,8,10,12,14]
row_seeds = [1,2,3]
col_seeds = [4,5,6]

# %%
generate_style_mix_human_from_outside(network_pkl, row_seeds, col_seeds, col_styles, truncation_psi, noise_mode, outdir)
# Out:
# Loading networks from "models/stylegan_human_v2_512.pkl"...
# Generating W vectors...
# Generating images...
# Generating style-mixed images...
# [W NNPACK.cpp:80] Could not initialize NNPACK! Reason: Unsupported hardware.
# Saving image grid...

# %%
fig = plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(1,1,1)
image = Image.open(out_path)
image_array = np.asarray(image)
ax1.imshow(image_array)
